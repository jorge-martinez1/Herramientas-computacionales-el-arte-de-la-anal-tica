# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ("games.csv")

# %%
df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-03-12  22101005            Final    1610612748       1610612750
# 1    2022-03-12  22101006            Final    1610612741       1610612739
# 2    2022-03-12  22101007            Final    1610612759       1610612754
# 3    2022-03-12  22101008            Final    1610612744       1610612749
# 4    2022-03-12  22101009            Final    1610612743       1610612761
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2021    1610612748     104.0        0.398        0.760  ...      23.0
# 1    2021    1610612741     101.0        0.443        0.933  ...      20.0
# 2    2021    1610612759     108.0        0.412        0.813  ...      28.0
# 3    2021    1610612744     122.0        0.484        0.933  ...      33.0
# 4    2021    1610612743     115.0        0.551        0.750  ...      32.0
#
# ...

# %%
df.tail()
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 25791    2014-10-06  11400007            Final    1610612737       1610612740
# 25792    2014-10-06  11400004            Final    1610612741       1610612764
# 25793    2014-10-06  11400005            Final    1610612747       1610612743
# 25794    2014-10-05  11400002            Final    1610612761       1610612758
# 25795    2014-10-04  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 25791    2014    1610612737      93.0        0.419        0.821  ...
# 25792    2014    1610612741      81.0        0.338        0.719  ...
# 25793    2014    1610612747      98.0        0.448        0.682  ...
# 25794    2014    1610612761      99.0        0.440        0.771  ...
# 25795    2014    1610612748      86.0        0.431        0.679  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25796 entries, 0 to 25795
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     25796 non-null  object
#  1   GAME_ID           25796 non-null  int64
#  2   GAME_STATUS_TEXT  25796 non-null  object
#  3   HOME_TEAM_ID      25796 non-null  int64
#  4   VISITOR_TEAM_ID   25796 non-null  int64
#  5   SEASON            25796 non-null  int64
#  6   TEAM_ID_home      25796 non-null  int64
#  7   PTS_home          25697 non-null  float64
#  8   FG_PCT_home       25697 non-null  float64
#  9   FT_PCT_home       25697 non-null  float64
#  10  FG3_PCT_home      25697 non-null  float64
#  11  AST_home          25697 non-null  float64
#  12  REB_home          25697 non-null  float64
#  13  TEAM_ID_away      25796 non-null  int64
#  14  PTS_away          25697 non-null  float64
#  15  FG_PCT_away       25697 non-null  float64
# ...

# %%
df.describe()
# Out:
#             GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        SEASON  \
# count  2.579600e+04  2.579600e+04     2.579600e+04  25796.000000
# mean   2.169208e+07  1.610613e+09     1.610613e+09   2011.798341
# std    5.496041e+06  8.638857e+00     8.654846e+00      5.397985
# min    1.030000e+07  1.610613e+09     1.610613e+09   2003.000000
# 25%    2.060109e+07  1.610613e+09     1.610613e+09   2007.000000
# 50%    2.120040e+07  1.610613e+09     1.610613e+09   2012.000000
# 75%    2.170070e+07  1.610613e+09     1.610613e+09   2016.000000
# max    5.200021e+07  1.610613e+09     1.610613e+09   2021.000000
#
#        TEAM_ID_home      PTS_home   FG_PCT_home   FT_PCT_home  FG3_PCT_home  \
# count  2.579600e+04  25697.000000  25697.000000  25697.000000  25697.000000
# mean   1.610613e+09    103.106044      0.460313      0.759705      0.355896
# std    8.638857e+00     13.174726      0.056629      0.100692      0.111940
# ...

# %%
df.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away',
#        'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
#        'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
df["PTS_away"]
# Out:
# 0        113.0
# 1         91.0
# 2        119.0
# 3        109.0
# 4        127.0
#          ...
# 25791     87.0
# 25792     85.0
# 25793     95.0
# 25794     94.0
# 25795     98.0
# Name: PTS_away, Length: 25796, dtype: float64

# %%
df[['PTS_home', 'PTS_away', 'REB_home', 'REB_away']]
# Out:
#        PTS_home  PTS_away  REB_home  REB_away
# 0         104.0     113.0      53.0      46.0
# 1         101.0      91.0      46.0      40.0
# 2         108.0     119.0      52.0      47.0
# 3         122.0     109.0      55.0      39.0
# 4         115.0     127.0      39.0      50.0
# ...         ...       ...       ...       ...
# 25791      93.0      87.0      50.0      43.0
# 25792      81.0      85.0      40.0      47.0
# 25793      98.0      95.0      45.0      43.0
# 25794      99.0      94.0      30.0      45.0
# 25795      86.0      98.0      42.0      42.0
#
# [25796 rows x 4 columns]

# %%
# Medidas de tendencia central
print(f"Promedio: {df['PTS_away'].mean()}")
print(f"Mediana: {df['PTS_away'].median()}")
print(f"Moda: {df['PTS_away'].mode()}")

# Medidas de dispersión
print(f"Desviación estándar: {df['PTS_away'].std()}")
print(f"Varianza: {df['PTS_away'].var()}")

# Medidas de posicionamiento
print(f"Mínimo: {df['PTS_away'].min()}")
print(f"Q1: {df['PTS_away'].quantile(0.25)}")
print(f"Q2: {df['PTS_away'].quantile(0.50)}")
print(f"Q3: {df['PTS_away'].quantile(0.75)}")
print(f"Máximo: {df['PTS_away'].max()}")
# Out:
# Promedio: 100.29411993617931
# Mediana: 100.0
# Moda: 0    98.0
# Name: PTS_away, dtype: float64
# Desviación estándar: 13.343016048469163
# Varianza: 178.03607726970566
# Mínimo: 33.0
# Q1: 91.0
# Q2: 100.0
# Q3: 109.0
# Máximo: 168.0

# %%
# Cajas y bigotes (box & whiskers) - Gráficas de cajas (boxplots)
df["PTS_away"].plot.box()
# Out:
# <Axes: >

# %%
df["PTS_away"].dtype
# Out:
# dtype('float64')

# %%
# Si encuentran una columna que se detectó como texto (object) y debería ser numérica
df["GAME_DATE_EST"] = pd.to_numeric(df["GAME_DATE_EST"].str.replace("-", ""))

# %%
columnas_númericas = []
columnas_no_númericas = []
for col in df.columns:
    if df[col].dtype == "object":
        columnas_no_númericas.append(col)
    else:
        columnas_númericas.append(col)
print(f"Columnas numéricas: {columnas_númericas}")
print(f"Columnas no numéricas: {columnas_no_númericas}")
# Out:
# Columnas numéricas: ['GAME_DATE_EST', 'GAME_ID', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away', 'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away', 'HOME_TEAM_WINS']
# Columnas no numéricas: ['GAME_STATUS_TEXT']

# %%
for col in columnas_númericas:
    df[col].plot.box(title=col)
    plt.show()

# %%
for col in columnas_númericas:
    df[col].plot.kde(title=col)
    plt.show()

# %%
df.head()
# Out:
#    GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0       20220312  22101005            Final    1610612748       1610612750
# 1       20220312  22101006            Final    1610612741       1610612739
# 2       20220312  22101007            Final    1610612759       1610612754
# 3       20220312  22101008            Final    1610612744       1610612749
# 4       20220312  22101009            Final    1610612743       1610612761
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2021    1610612748     104.0        0.398        0.760  ...      23.0
# 1    2021    1610612741     101.0        0.443        0.933  ...      20.0
# 2    2021    1610612759     108.0        0.412        0.813  ...      28.0
# 3    2021    1610612744     122.0        0.484        0.933  ...      33.0
# 4    2021    1610612743     115.0        0.551        0.750  ...      32.0
#
# ...

# %%
df.groupby("SEASON")["PTS_away"].mean().reset_index().nlargest(5, "PTS_away")
# Out:
#     SEASON    PTS_away
# 17    2020  111.237790
# 16    2019  110.466559
# 15    2018  109.565312
# 18    2021  108.792751
# 14    2017  104.925470

# %%
df.groupby("SEASON")["PTS_away"].mean().reset_index().nlargest(5, "PTS_away").plot.bar(x="SEASON", y="PTS_away")
# Out:
# <Axes: xlabel='SEASON'>

# %%
df["SEASON"].value_counts().nlargest(5)
# Out:
# SEASON
# 2005    1432
# 2013    1427
# 2008    1425
# 2009    1424
# 2010    1422
# Name: count, dtype: int64

# %%
df["SEASON"].value_counts().nlargest(5).plot.pie(autopct="%.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["PTS_away"].value_counts(bins=10)
# Out:
# (87.0, 100.5]                 9007
# (100.5, 114.0]                8689
# (73.5, 87.0]                  3900
# (114.0, 127.5]                3000
# (127.5, 141.0]                 611
# (60.0, 73.5]                   422
# (141.0, 154.5]                  48
# (46.5, 60.0]                    14
# (154.5, 168.0]                   5
# (32.864000000000004, 46.5]       1
# Name: count, dtype: int64

# %%
df["PTS_away"].plot.hist(bins=10, title="Histograma de PTS_away")
# Out:
# <Axes: title={'center': 'Histograma de PTS_away'}, ylabel='Frequency'>

# %%
df["SEASON"].unique()
# Out:
# array([2021, 2020, 2019, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006,
#        2005, 2004, 2003, 2018, 2017, 2016, 2015, 2014])

# %%
df.loc[df["SEASON"] == 2021]
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0          20220312  22101005            Final    1610612748       1610612750
# 1          20220312  22101006            Final    1610612741       1610612739
# 2          20220312  22101007            Final    1610612759       1610612754
# 3          20220312  22101008            Final    1610612744       1610612749
# 4          20220312  22101009            Final    1610612743       1610612761
# ...             ...       ...              ...           ...              ...
# 1071       20211004  12100007            Final    1610612759       1610612762
# 1072       20211004  12100008            Final    1610612757       1610612744
# 1073       20211004  12100009            Final    1610612758       1610612756
# 1074       20211004  12100010            Final    1610612746       1610612743
# 1075       20211003  12100001            Final    1610612747       1610612751
#
# ...

# %%
df.loc[df["PTS_away"] <= 50]
# Out:
#        GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  \
# 12777       20071019  10700072            Final    1610612738
#
#        VISITOR_TEAM_ID  SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  \
# 12777       1610612751    2007    1610612738      36.0        0.414
#
#        FT_PCT_home  ...  AST_home  REB_home  TEAM_ID_away  PTS_away  \
# 12777         0.75  ...       8.0      18.0    1610612751      33.0
#
#        FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 12777         0.29        0.722         0.333       7.0      19.0
#
#        HOME_TEAM_WINS
# 12777               1
#
# [1 rows x 21 columns]

# %%
# and -> &
# or -> |
# not -> ~
# Filas donde PTS_home estuvo abajo de 20 y PTS_away estuvo arriba de 25

df.loc[(df["PTS_home"] < 20) & (df["PTS_away"] > 25), ["GAME_ID", "PTS_home", "PTS_away"]]
# Out:
# Empty DataFrame
# Columns: [GAME_ID, PTS_home, PTS_away]
# Index: []

# %%
# Filas donde PTS_home estuvo abajo de 90 y PTS_away estuvo arriba de 120
df.loc[(df["PTS_home"] < 90) & (df["PTS_away"] > 120), ["GAME_ID", "PTS_home", "PTS_away"]]
# Out:
#         GAME_ID  PTS_home  PTS_away
# 145    22100869      87.0     135.0
# 722    22100283      88.0     123.0
# 1023   12100048      59.0     127.0
# 1456   22000808      87.0     124.0
# 1518   22000748      81.0     125.0
# 1659   22000031      73.0     124.0
# 1827   22000525      84.0     133.0
# 2597   21900905      88.0     127.0
# 5286   21200665      80.0     125.0
# 5500   21200439      88.0     123.0
# 6360   21100761      84.0     121.0
# 8566   11000014      78.0     129.0
# 9240   20900646      78.0     128.0
# 9954   10900053      86.0     121.0
# 10053  40800154      63.0     121.0
# 10096  20801228      85.0     126.0
# 10990  20800323      88.0     122.0
# 13101  20601053      89.0     126.0
# 13156  20600992      74.0     124.0
# 18794  11900007      89.0     125.0
# 19547  21800554      84.0     122.0
# 19728  21800383      77.0     133.0
# 19814  21800299      88.0     121.0
# 19882  21800230      83.0     122.0
# 20682  21700810      81.0     129.0
# ...

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2) Cargar dataset
df = pd.read_csv("games.csv")

# %%
df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-03-12  22101005            Final    1610612748       1610612750
# 1    2022-03-12  22101006            Final    1610612741       1610612739
# 2    2022-03-12  22101007            Final    1610612759       1610612754
# 3    2022-03-12  22101008            Final    1610612744       1610612749
# 4    2022-03-12  22101009            Final    1610612743       1610612761
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2021    1610612748     104.0        0.398        0.760  ...      23.0
# 1    2021    1610612741     101.0        0.443        0.933  ...      20.0
# 2    2021    1610612759     108.0        0.412        0.813  ...      28.0
# 3    2021    1610612744     122.0        0.484        0.933  ...      33.0
# 4    2021    1610612743     115.0        0.551        0.750  ...      32.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25796 entries, 0 to 25795
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     25796 non-null  object
#  1   GAME_ID           25796 non-null  int64
#  2   GAME_STATUS_TEXT  25796 non-null  object
#  3   HOME_TEAM_ID      25796 non-null  int64
#  4   VISITOR_TEAM_ID   25796 non-null  int64
#  5   SEASON            25796 non-null  int64
#  6   TEAM_ID_home      25796 non-null  int64
#  7   PTS_home          25697 non-null  float64
#  8   FG_PCT_home       25697 non-null  float64
#  9   FT_PCT_home       25697 non-null  float64
#  10  FG3_PCT_home      25697 non-null  float64
#  11  AST_home          25697 non-null  float64
#  12  REB_home          25697 non-null  float64
#  13  TEAM_ID_away      25796 non-null  int64
#  14  PTS_away          25697 non-null  float64
#  15  FG_PCT_away       25697 non-null  float64
# ...

# %%
numerical_columns = []
categorical_columns = []
for column in df.columns:
    if df[column].dtype == 'object':
        categorical_columns.append(column)
    else:
        numerical_columns.append(column)

# %%
preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numerical_columns),
    ("cat", OneHotEncoder(), categorical_columns)
])

# %%
X = preprocessor.fit_transform(df)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
numerical_columns = []
categorical_columns = []
for column in df.columns:
    if df[column].dtype == 'object':
        categorical_columns.append(column)
    else:
        numerical_columns.append(column)

# %%
preprocessor = ColumnTransformer([
    ("num",
     Pipeline([
         ("imputer", SimpleImputer(strategy="median")),
         ("scaler", StandardScaler())
     ]),
     numerical_columns),
    ("cat",
     Pipeline([
         ("imputer", SimpleImputer(strategy="most_frequent")),
         ("onehot", OneHotEncoder(handle_unknown="ignore"))
     ]),
     categorical_columns)
])

# %%
X = preprocessor.fit_transform(df)

# %%
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)
    diff = inertias[-2] - inertias[-1] if k > 1 else 0
    print(f'K={k}, Inercia = {kmeans.inertia_:.6f} – Diferencia = {diff:.6f}')
# Out:
# K=1, Inercia = 515911.726237 – Diferencia = 0.000000
# K=2, Inercia = 463368.736306 – Diferencia = 52542.989930
# K=3, Inercia = 424014.332523 – Diferencia = 39354.403783
# K=4, Inercia = 406540.353404 – Diferencia = 17473.979119
# K=5, Inercia = 390395.032471 – Diferencia = 16145.320933
# K=6, Inercia = 379691.215794 – Diferencia = 10703.816677
# K=7, Inercia = 369448.367784 – Diferencia = 10242.848010
# K=8, Inercia = 361541.748396 – Diferencia = 7906.619388
# K=9, Inercia = 353924.574460 – Diferencia = 7617.173936
# K=10, Inercia = 348492.919042 – Diferencia = 5431.655418

# %%
sns.lineplot(x=range(1, 11), y=inertias, marker="o")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Inercia (SSE - Suma de errores al cuadrado)")
plt.title("Método del codo para determinar el número óptimo de clusters")
plt.xticks(range(1, 11))
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X)
df["Cluster"] = kmeans.labels_
df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-03-12  22101005            Final    1610612748       1610612750
# 1    2022-03-12  22101006            Final    1610612741       1610612739
# 2    2022-03-12  22101007            Final    1610612759       1610612754
# 3    2022-03-12  22101008            Final    1610612744       1610612749
# 4    2022-03-12  22101009            Final    1610612743       1610612761
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  REB_home  \
# 0    2021    1610612748     104.0        0.398        0.760  ...      53.0
# 1    2021    1610612741     101.0        0.443        0.933  ...      46.0
# 2    2021    1610612759     108.0        0.412        0.813  ...      52.0
# 3    2021    1610612744     122.0        0.484        0.933  ...      55.0
# 4    2021    1610612743     115.0        0.551        0.750  ...      39.0
#
# ...

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=df["Cluster"])
plt.title("Visualización de clusters con PCA")
plt.show()

# %%
df["Cluster"].value_counts()
# Out:
# Cluster
# 0    5429
# 1    5321
# 2    5055
# 4    4996
# 3    4995
# Name: count, dtype: int64

# %%
df[numerical_columns + ["Cluster"]].groupby("Cluster").mean()
# Out:
#               GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID       SEASON  \
# Cluster
# 0        2.154962e+07  1.610613e+09     1.610613e+09  2010.664948
# 1        2.178290e+07  1.610613e+09     1.610613e+09  2013.933095
# 2        2.178330e+07  1.610613e+09     1.610613e+09  2010.369931
# 3        2.129415e+07  1.610613e+09     1.610613e+09  2010.013614
# 4        2.205571e+07  1.610613e+09     1.610613e+09  2013.985989
#
#          TEAM_ID_home    PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# Cluster
# 0        1.610613e+09  103.009427     0.469895     0.761219      0.376397
# 1        1.610613e+09  104.555535     0.454591     0.761814      0.348562
# 2        1.610613e+09  100.327179     0.454700     0.755626      0.345937
# 3        1.610613e+09   88.414150     0.402081     0.734885      0.270390
# 4        1.610613e+09  118.975180     0.519187     0.784437      0.435977
#
#           AST_home   REB_home  TEAM_ID_away    PTS_away  FG_PCT_away  \
# Cluster
# ...

# %%
df[categorical_columns + ["Cluster"]].groupby("Cluster").agg(lambda x: x.mode()[0])
# Out:
#         GAME_DATE_EST GAME_STATUS_TEXT
# Cluster
# 0          2006-11-22            Final
# 1          2020-12-26            Final
# 2          2008-02-29            Final
# 3          2015-03-25            Final
# 4          2018-04-03            Final

# %%
sns.barplot(df, x="Cluster", y="PTS_away", estimator="mean")
# Out:
# <Axes: xlabel='Cluster', ylabel='PTS_away'>

# %%
tmp = df.dropna(subset=["PTS_home","PTS_away","Cluster"])
sns.scatterplot(data=tmp, x="PTS_home", y="PTS_away", hue="Cluster")
plt.title("Relación entre PTS_home y PTS_away por cluster")
plt.xlabel("PTS_home")
plt.ylabel("PTS_away")
plt.show()
